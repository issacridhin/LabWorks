# %% [markdown]
# <a href="https://colab.research.google.com/github/issacridhin/LabWorks/blob/LLM/2348546_LLMLab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain
# !pip install langchain-groq

# %%
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_groq import ChatGroq
import os

# %%
# Retrieve the API key from the environment variable
api_key = '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'
# Print the API key to ensure it is loaded correctly (for debugging purposes, remove this in production)
print(api_key)
# Out:
# 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

# %%
model = ChatGroq(api_key = api_key ,model_name = 'gemma2-9b-it', temperature = 0.4)

# %% [markdown]
# Question Answering

# %%
template = (
    """
    you're a story teller expert
answer : {answer}
"""
)

# %%
prompt = PromptTemplate.from_template(template=template)

# %%
parser = StrOutputParser()
chain =  prompt | model | parser

# %%
result = chain.invoke({'answer':"Once upon a time there lived a chef Ridhin. He loves to cook. While he ...."})
print(result)
# Out:
# ...was known throughout the village for his delectable curries, his true passion lay in creating dishes that told stories. Each spice, each herb, each carefully chosen ingredient held a memory, a legend, a whisper of the past.
#
# One day, a renowned food critic, Madame Eloise, arrived in the village.  Her discerning palate had tasted the finest cuisines across the land, and her reviews held the power to make or break a chef's career.  Ridhin, determined to impress her, decided to cook a dish unlike any she had ever encountered before.
#
# He gathered the rarest ingredients: saffron threads spun from the dreams of desert flowers, cinnamon bark imbued with the whispers of ancient forests, and a single, glistening pearl harvested from the depths of a forgotten ocean.
#
# ...
